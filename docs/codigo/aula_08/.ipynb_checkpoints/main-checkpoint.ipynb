# %%
import pandas as pd
import plotly as px

# %%
dados = pd.read_csv('./dados/lancamentos-comerciais-por-distribuidoras.csv', sep=';')

# %%
# Tamanho do Dataframe
print(f'Temos {len(dados)} linhas.')
# Out:
# Temos 6157 linhas

# %%
# Primeira visualização
# Na descrição do portal de dados abertos há apenas o nome das colunas:
# Data de lançamento da obra; Título original; CPB/ROE; Tipo da obra; \
# País da obra; Público total; Renda total; Razão social Distribuidora; \
# Registro Distribuidora; CNPJ Distribuidora.

# Vamos verificar:

dados.columns
# Out:
# Index(['DATA_LANCAMENTO_OBRA', 'TITULO_ORIGINAL', 'CPB_ROE', 'TIPO_OBRA',
#        'PAIS_OBRA', 'PUBLICO_TOTAL', 'RENDA_TOTAL',
#        'RAZAO_SOCIAL_DISTRIBUIDORA', 'REGISTRO_DISTRIBUIDORA',
#        'CNPJ_DISTRIBUIDORA'],
#       dtype='object')

# %%
# Vamos verificar os dados melhor:

dados.head(5)
# Out:
#   DATA_LANCAMENTO_OBRA                              TITULO_ORIGINAL  \
# 0           08/08/2024                          MAIS PESADO É O CÉU
# 1           31/07/2024  BLACKPINK WORLD TOUR [BORN PINK] IN CINEMAS
# 2           31/07/2024                             ESTRANHO CAMINHO
# 3           25/07/2024                         AKU WA SONZAI SHINAI
# 4           25/07/2024                         DEADPOOL & WOLVERINE
#
#           CPB_ROE     TIPO_OBRA       PAIS_OBRA  PUBLICO_TOTAL  \
# 0  B2300060700000        FICÇÃO          BRASIL            364
# 1  E2400243000000  VÍDEOMUSICAL   CORÉIA DO SUL          18279
# 2  B2300296700000        FICÇÃO          BRASIL             23
# 3  E2400245700000        FICÇÃO           JAPÃO           5025
# 4  E2400232500000        FICÇÃO  ESTADOS UNIDOS        3386450
#
#         RENDA_TOTAL                 RAZAO_SOCIAL_DISTRIBUIDORA  \
# 0       R$ 3.493,00         SEREIA DISTRIBUIÇÃO DE FILMES LTDA
# 1     R$ 618.816,43  UNITED CINEMAS INTERNATIONAL BRASIL LTDA.
# 2         R$ 353,79                        EMBAUBA FILMES LTDA
# 3      R$ 95.047,76  TAG CULTURAL DISTRIBUIDORA DE FILMES LTDA
# 4  R$ 71.928.236,32     THE WALT DISNEY COMPANY (BRASIL) LTDA.
#
#    REGISTRO_DISTRIBUIDORA  CNPJ_DISTRIBUIDORA
# 0                 13753.0  08.905.114/0001-92
# 1                   749.0  01.289.530/0001-64
# 2                 23638.0  15.144.532/0001-70
# 3                   173.0  03.599.148/0001-82
# 4                 18398.0  73.042.962/0001-87

# %%
# Vamos fazer alguns filtros:

# Qual é a renda total máxima?
dados.RENDA_TOTAL.max()
# Out:
# 'R$ 999,62'

# %%
dados.info()
# RENDA_TOTAL é do tipo object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6157 entries, 0 to 6156
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DATA_LANCAMENTO_OBRA        6157 non-null   object
#  1   TITULO_ORIGINAL             6157 non-null   object
#  2   CPB_ROE                     6157 non-null   object
#  3   TIPO_OBRA                   6157 non-null   object
#  4   PAIS_OBRA                   6156 non-null   object
#  5   PUBLICO_TOTAL               6157 non-null   int64
#  6   RENDA_TOTAL                 6157 non-null   object
#  7   RAZAO_SOCIAL_DISTRIBUIDORA  6157 non-null   object
#  8   REGISTRO_DISTRIBUIDORA      6156 non-null   float64
#  9   CNPJ_DISTRIBUIDORA          6157 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 481.1+ KB

# %%
# Vamos tentar mudar o tipo com o método astype, que Transmitir um objeto pandas para um dtype especificado
dados['RENDA_TOTAL'].astype('float64')
# Não foi possível converter as strings em float, por conta de do separador decimal.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 2
#       1 # Vamos tentar mudar o tipo com o método astype, que Transmitir um objeto pandas para um dtype especificado
# ----> 2 dados['RENDA_TOTAL'].astype('float64')
#
# File ~/Dropbox/Ágora/Mentores/fundamentos_de_algoritmos_e_introducao_a_programacao_python_2/producao_material/web/docs/codigo/aula_08/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/Dropbox/Ágora/Mentores/fundamentos_de_algoritmos_e_introducao_a_programacao_python_2/producao_material/web/docs/codigo/aula_08/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/Dropbox/Ágora/Mentores/fundamentos_de_algoritmos_e_introducao_a_programacao_python_2/producao_material/web/docs/codigo/aula_08/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/Dropbox/Ágora/Mentores/fundamentos_de_algoritmos_e_introducao_a_programacao_python_2/producao_material/web/docs/codigo/aula_08/.venv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/Dropbox/Ágora/Mentores/fundamentos_de_algoritmos_e_introducao_a_programacao_python_2/producao_material/web/docs/codigo/aula_08/.venv/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/Dropbox/Ágora/Mentores/fundamentos_de_algoritmos_e_introducao_a_programacao_python_2/producao_material/web/docs/codigo/aula_08/.venv/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/Dropbox/Ágora/Mentores/fundamentos_de_algoritmos_e_introducao_a_programacao_python_2/producao_material/web/docs/codigo/aula_08/.venv/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'R$ 3.493,00'

# %%
float('R$ 3.493,00')
'''
Temos dois problemas, a string possui valores não-numéricos, separador decimal \
não é reconhecido pelo tipo float e ainda possui um separador de classe decimais.
'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 float('R$ 3.493,00')
#
# ValueError: could not convert string to float: 'R$ 3.493,00'

# %%
float('R$ 3.493,00'[3:].replace('.','').replace(',','.'))
# Out:
# 3493.0

# %%
float('3.493')
# Out:
# 3.493

# %%
def converte_string(valor):
    return valor[3:].replace('.','').replace(',','.')

# %%
dados['RENDA_TOTAL'] = dados['RENDA_TOTAL'].apply(converte_string)
dados['RENDA_TOTAL']
# Out:
# 0           3493.00
# 1         618816.43
# 2            353.79
# 3          95047.76
# 4       71928236.32
#            ...
# 6152     2350017.91
# 6153       37557.00
# 6154    50545885.00
# 6155     9590392.25
# 6156      141070.93
# Name: RENDA_TOTAL, Length: 6157, dtype: object

# %%
dados['RENDA_TOTAL'] = dados['RENDA_TOTAL'].astype('float64')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6157 entries, 0 to 6156
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DATA_LANCAMENTO_OBRA        6157 non-null   object
#  1   TITULO_ORIGINAL             6157 non-null   object
#  2   CPB_ROE                     6157 non-null   object
#  3   TIPO_OBRA                   6157 non-null   object
#  4   PAIS_OBRA                   6156 non-null   object
#  5   PUBLICO_TOTAL               6157 non-null   int64
#  6   RENDA_TOTAL                 6157 non-null   float64
#  7   RAZAO_SOCIAL_DISTRIBUIDORA  6157 non-null   object
#  8   REGISTRO_DISTRIBUIDORA      6156 non-null   float64
#  9   CNPJ_DISTRIBUIDORA          6157 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 481.1+ KB

# %%
dados.RENDA_TOTAL.max()
# Out:
# np.float64(425729796.94)

# %%
filme_mais_caro = dados.loc[dados['RENDA_TOTAL'] == 425729796.94]
filme_mais_caro
# Out:
#    DATA_LANCAMENTO_OBRA TITULO_ORIGINAL         CPB_ROE TIPO_OBRA  \
# 39           20/06/2024    INSIDE OUT 2  E2400179900000  ANIMAÇÃO
#
#          PAIS_OBRA  PUBLICO_TOTAL   RENDA_TOTAL  \
# 39  ESTADOS UNIDOS       21473303  4.257298e+08
#
#                 RAZAO_SOCIAL_DISTRIBUIDORA  REGISTRO_DISTRIBUIDORA  \
# 39  THE WALT DISNEY COMPANY (BRASIL) LTDA.                 18398.0
#
#     CNPJ_DISTRIBUIDORA
# 39  73.042.962/0001-87

# %%
dados[dados.PAIS_OBRA == 'BRASIL'].head(2)
# Out:
#   DATA_LANCAMENTO_OBRA      TITULO_ORIGINAL         CPB_ROE TIPO_OBRA  \
# 0           08/08/2024  MAIS PESADO É O CÉU  B2300060700000    FICÇÃO
# 2           31/07/2024     ESTRANHO CAMINHO  B2300296700000    FICÇÃO
#
#   PAIS_OBRA  PUBLICO_TOTAL  RENDA_TOTAL          RAZAO_SOCIAL_DISTRIBUIDORA  \
# 0    BRASIL            364      3493.00  SEREIA DISTRIBUIÇÃO DE FILMES LTDA
# 2    BRASIL             23       353.79                 EMBAUBA FILMES LTDA
#
#    REGISTRO_DISTRIBUIDORA  CNPJ_DISTRIBUIDORA
# 0                 13753.0  08.905.114/0001-92
# 2                 23638.0  15.144.532/0001-70

# %%
dados[dados.PAIS_OBRA == 'BRASIL'].RENDA_TOTAL.max()
# Out:
# np.float64(169382611.11)

# %%
filme_mais_caro_brasil = dados[dados.PAIS_OBRA == 'BRASIL'].loc[dados['RENDA_TOTAL'] == 169382611.11]
filme_mais_caro_brasil
# Out:
#      DATA_LANCAMENTO_OBRA         TITULO_ORIGINAL         CPB_ROE TIPO_OBRA  \
# 1642           26/12/2019  MINHA MÃE É UMA PEÇA 3  B1900576900000    FICÇÃO
#
#      PAIS_OBRA  PUBLICO_TOTAL   RENDA_TOTAL  \
# 1642    BRASIL       10936882  1.693826e+08
#
#                     RAZAO_SOCIAL_DISTRIBUIDORA  REGISTRO_DISTRIBUIDORA  \
# 1642  FREESPIRIT DISTRIBUIDORA DE FILMES LTDA.                  4904.0
#
#       CNPJ_DISTRIBUIDORA
# 1642  07.616.202/0001-01

# %%
dados.sort_values('RENDA_TOTAL', ascending=False)
# Out:
#      DATA_LANCAMENTO_OBRA                                    TITULO_ORIGINAL  \
# 39             20/06/2024                                       INSIDE OUT 2
# 1944           25/04/2019                                  AVENGERS: ENDGAME
# 1149           16/12/2021                            SPIDER-MAN: NO WAY HOME
# 1854           18/07/2019                                      THE LION KING
# 759            15/12/2022                           AVATAR: THE WAY OF WATER
# ...                   ...                                                ...
# 2540           01/02/2018                                 THE SHAPE OF WATER
# 345            15/11/2023  THE HUNGER GAMES – BALLAD OF SONGBIRDS AND SNAKES
# 1520           08/10/2020                                         ZONA ÁRIDA
# 145            11/04/2024                             AS LINHAS DA MINHA MÃO
# 4954           07/09/2012                                      CARA OU COROA
#
#              CPB_ROE     TIPO_OBRA       PAIS_OBRA  PUBLICO_TOTAL  \
# 39    E2400179900000      ANIMAÇÃO  ESTADOS UNIDOS       21473303
# 1944  E1900107800000        FICÇÃO  ESTADOS UNIDOS       19656475
# 1149  E2100453300000        FICÇÃO  ESTADOS UNIDOS       17382043
# 1854  E1900267700000        FICÇÃO  ESTADOS UNIDOS       16249412
# 759   E2200431200000        FICÇÃO  ESTADOS UNIDOS       11708276
# ...              ...           ...             ...            ...
# 2540  E1700442300000        FICÇÃO  ESTADOS UNIDOS             13
# 345   E2300444800000        FICÇÃO  ESTADOS UNIDOS              1
# 1520  B2000259000000  DOCUMENTÁRIO          BRASIL              1
# 145   B2300145400000  DOCUMENTÁRIO          BRASIL              1
# 4954  B1201586300000        FICÇÃO          BRASIL              1
#
#        RENDA_TOTAL                RAZAO_SOCIAL_DISTRIBUIDORA  \
# 39    4.257298e+08    THE WALT DISNEY COMPANY (BRASIL) LTDA.
# 1944  3.386250e+08    THE WALT DISNEY COMPANY (BRASIL) LTDA.
# 1149  3.174329e+08    COLUMBIA TRISTAR FILMES DO BRASIL LTDA
# 1854  2.659039e+08    THE WALT DISNEY COMPANY (BRASIL) LTDA.
# 759   2.413956e+08    THE WALT DISNEY COMPANY (BRASIL) LTDA.
# ...            ...                                       ...
# 2540  2.600000e+01    THE WALT DISNEY COMPANY (BRASIL) LTDA.
# 345   2.000000e+01                         CINE CAXAMBU LTDA
# 1520  1.200000e+01         OLHAR DISTRIBUICAO DE FILMES LTDA
# 145   1.000000e+01  KOMPANHIA TEATRO MULTIMÍDIA DE SÃO PAULO
# 4954  3.410000e+00                    CIRCUITO CINEARTE LTDA
#
#       REGISTRO_DISTRIBUIDORA  CNPJ_DISTRIBUIDORA
# 39                   18398.0  73.042.962/0001-87
# 1944                 18398.0  73.042.962/0001-87
# 1149                    84.0  00.979.601/0001-98
# 1854                 18398.0  73.042.962/0001-87
# 759                  18398.0  73.042.962/0001-87
# ...                      ...                 ...
# 2540                 18398.0  73.042.962/0001-87
# 345                  53644.0  50.552.809/0001-02
# 1520                 37242.0  28.083.221/0001-90
# 145                  57643.0  60.740.149/0001-39
# 4954                  1083.0  01.425.583/0001-65
#
# [6157 rows x 10 columns]

# %%
dados.sort_values('RENDA_TOTAL', ascending=False).plot(x='PAIS_OBRA', y='RENDA_TOTAL', kind='scatter')

# %%
quant_filmes_brasil = len(dados[dados.PAIS_OBRA == 'BRASIL'])
quant_filmes_coreanos = len(dados[dados.PAIS_OBRA == 'CORÉIA DO SUL'])
print(quant_filmes_brasil,quant_filmes_coreanos)
# Out:
# 1922 44

# %%
quant_renda = dados[['PAIS_OBRA', 'TITULO_ORIGINAL']].groupby('PAIS_OBRA').count().sort_values('PAIS_OBRA', ascending=False).reset_index()

# %%
quant_renda.PAIS_OBRA.unique()
# Out:
# array(['ÍNDIA', 'ÁUSTRIA', 'ÁFRICA DO SUL', 'VENEZUELA', 'URUGUAI',
#        'UCRÂNIA', 'TURQUIA', 'TUNÍSIA', 'TERRITÓRIOS PALESTINOS OCUPADOS',
#        'TAIWAN', 'SÉRVIA', 'SUÍÇA', 'SUÉCIA', 'RÚSSIA', 'ROMÊNIA',
#        'REPÚBLICA TCHECA', 'REPÚBLICA DOMINICANA', 'REINO UNIDO',
#        'PORTUGAL', 'POLÔNIA', 'PERU', 'PARAGUAI', 'PANAMÁ',
#        'NOVA ZELÂNDIA', 'NORUEGA', 'MÔNACO', 'MÉXICO', 'MALÁSIA',
#        'MACEDÔNIA (REPÚBLICA YUGOSLAVA)', 'LÍBANO', 'LUXEMBURGO', 'JAPÃO',
#        'IÊMEN', 'ITÁLIA', 'ISRAEL', 'ISLÂNDIA', 'IRÃ', 'IRLANDA',
#        'IRAQUE', 'INGLATERRA', 'INDONÉSIA', 'HUNGRIA', 'HONG KONG',
#        'HOLANDA', 'GUATEMALA', 'GRÉCIA', 'FRANÇA', 'FINLÂNDIA',
#        'FILIPINAS', 'ESTÔNIA', 'ESTADOS UNIDOS', 'ESPANHA', 'ESLOVÊNIA',
#        'ESLOVÁQUIA', 'EMIRADOS ÁRABES UNIDOS', 'EGITO', 'DINAMARCA',
#        'CUBA', 'CROÁCIA (HRVATSKA)', 'COSTA RICA', 'CORÉIA DO SUL',
#        'CORÉIA DO NORTE', 'CONGO', 'COLÔMBIA', 'CINGAPURA', 'CHINA',
#        'CHILE', 'CHADE', 'CANADÁ', 'CAMBOJA', 'BÓSNIA-HERZEGÓVINA',
#        'BÉLGICA', 'BUTÃO', 'BULGÁRIA', 'BRASIL', 'BELARUS (BIELORUSSIA)',
#        'AUSTRÁLIA', 'ARÁBIA SAUDITA', 'ARGÉLIA', 'ARGENTINA', 'ALEMANHA',
#        'ALBÂNIA', 'AFEGANISTÃO'], dtype=object)

# %%
rendas = []
for pais in quant_renda.PAIS_OBRA.unique():
    renda = dados[dados.PAIS_OBRA == pais].RENDA_TOTAL.mean()
    rendas.append(renda)
    
quant_renda['RENDA_MÉDIA'] = rendas
quant_renda
# Out:
#         PAIS_OBRA  TITULO_ORIGINAL   RENDA_MÉDIA  \
# 0           ÍNDIA                4  2.470077e+05
# 1         ÁUSTRIA               12  2.399169e+05
# 2   ÁFRICA DO SUL                8  1.038687e+06
# 3       VENEZUELA                4  5.003331e+04
# 4         URUGUAI                8  9.348234e+04
# ..            ...              ...           ...
# 78        ARGÉLIA                4  4.199222e+04
# 79      ARGENTINA              123  5.015840e+05
# 80       ALEMANHA              250  7.595710e+05
# 81        ALBÂNIA                1  3.922000e+03
# 82    AFEGANISTÃO                2  4.985151e+04
#
#                 RENDA_MÉDIA_POR_FILME
# 0     0    61751.91875
# dtype: float64
# 1    1    19993.070972
# dtype: float64
# 2     2    129835.8625
# dtype: float64
# 3      3    12508.3275
# dtype: float64
# 4    4    11685.292031
# dtype: float64
# ..                                ...
# 78  78    10498.054375
# dtype: float64
# 79   79    4077.918314
# dtype: float64
# 80   80    3038.283846
# dtype: float64
# 81        81    3922.0
# dtype: float64
# 82     82    24925.755
# dtype: float64
#
# [83 rows x 4 columns]

# %%
print(quant_renda[quant_renda.PAIS_OBRA == 'BRASIL'].RENDA_MÉDIA.min())
# Out:
# 1671120.7638761706

# %%
rendas_filme = []
for pais in quant_renda.PAIS_OBRA.unique():
    renda_filme = quant_renda[quant_renda.PAIS_OBRA == pais].RENDA_MÉDIA.min() / quant_renda[quant_renda.PAIS_OBRA == pais].TITULO_ORIGINAL.min()
    rendas_filme.append(renda_filme)
quant_renda['RENDA_MÉDIA_POR_FILME'] = rendas_filme
quant_renda
# Out:
#         PAIS_OBRA  TITULO_ORIGINAL   RENDA_MÉDIA  RENDA_MÉDIA_POR_FILME
# 0           ÍNDIA                4  2.470077e+05           61751.918750
# 1         ÁUSTRIA               12  2.399169e+05           19993.070972
# 2   ÁFRICA DO SUL                8  1.038687e+06          129835.862500
# 3       VENEZUELA                4  5.003331e+04           12508.327500
# 4         URUGUAI                8  9.348234e+04           11685.292031
# ..            ...              ...           ...                    ...
# 78        ARGÉLIA                4  4.199222e+04           10498.054375
# 79      ARGENTINA              123  5.015840e+05            4077.918314
# 80       ALEMANHA              250  7.595710e+05            3038.283846
# 81        ALBÂNIA                1  3.922000e+03            3922.000000
# 82    AFEGANISTÃO                2  4.985151e+04           24925.755000
#
# [83 rows x 4 columns]

# %%
dados.sort_values('RENDA_TOTAL', ascending=False).plot(x='PAIS_OBRA', y='RENDA_TOTAL', kind='scatter')

# %%
quant_renda.sort_values('RENDA_MÉDIA_POR_FILME', ascending=False).plot(x='RENDA_MÉDIA_POR_FILME', y='PAIS_OBRA', kind='hist')

# %%
import zipfile
# Visualizando o que há dentro do arquivvo do tipo zip:
with zipfile.ZipFile('./dados/obras-nao-pub-brasileiras-csv.zip') as arq_zip:
    print(arq_zip.namelist())
# Out:
# ['obras-nao-pub-brasileiras-2002.csv', 'obras-nao-pub-brasileiras-2003.csv', 'obras-nao-pub-brasileiras-2004.csv', 'obras-nao-pub-brasileiras-2005.csv', 'obras-nao-pub-brasileiras-2006.csv', 'obras-nao-pub-brasileiras-2007.csv', 'obras-nao-pub-brasileiras-2008.csv', 'obras-nao-pub-brasileiras-2009.csv', 'obras-nao-pub-brasileiras-2010.csv', 'obras-nao-pub-brasileiras-2011.csv', 'obras-nao-pub-brasileiras-2012.csv', 'obras-nao-pub-brasileiras-2013.csv', 'obras-nao-pub-brasileiras-2014.csv', 'obras-nao-pub-brasileiras-2015.csv', 'obras-nao-pub-brasileiras-2016.csv', 'obras-nao-pub-brasileiras-2017.csv', 'obras-nao-pub-brasileiras-2018.csv', 'obras-nao-pub-brasileiras-2019.csv', 'obras-nao-pub-brasileiras-2020.csv', 'obras-nao-pub-brasileiras-2021.csv', 'obras-nao-pub-brasileiras-2022.csv', 'obras-nao-pub-brasileiras-2023.csv', 'obras-nao-pub-brasileiras-2024.csv']

# %%
with zipfile.ZipFile('./dados/obras-nao-pub-brasileiras-csv.zip') as arq_zip:
    with arq_zip.open('obras-nao-pub-brasileiras-2024.csv') as arq_csv:
        obras_nao_pub_brasileiras_2024 = pd.read_csv(arq_csv, sep=';')

# %%
obras_nao_pub_brasileiras_2024
# Out:
#                                    TITULO_ORIGINAL             CPB  \
# 0     "DESCOSTURANDO COM HERCHCOVITCH" TEMPORADA 2  B2400134000000
# 1                                 (IN)CONFIDENCIAS  B2400151600000
# 2                                      (IN)VISÍVEL  B2400325900000
# 3                                            /CHAT  B2400308300000
# 4                          02 DE JULHO: A RETOMADA  B2400226700000
# ...                                            ...             ...
# 2373                          É POR VOCÊ QUE CANTO  B2400285500000
# 2374                                  É TUDO NOSSO  B2400041300000
# 2375                                    É UMA PENA  B2400184600000
# 2376                                       ÌNTERIM  B2400042500000
# 2377                                        ÓTIMA!  B2400201600000
#
#      DATA_EMISSAO_CPB SITUACAO_OBRA     TIPO_OBRA         SUBTIPO_OBRA  \
# 0          04/04/2024      DEFERIDO  REALITY-SHOW                  NaN
# 1          15/04/2024      DEFERIDO    VARIEDADES                  NaN
# 2          19/08/2024      DEFERIDO  DOCUMENTÁRIO                  NaN
# 3          31/07/2024      DEFERIDO    VARIEDADES                  NaN
# 4          04/06/2024      DEFERIDO  DOCUMENTÁRIO                  NaN
# ...               ...           ...           ...                  ...
# 2373       18/07/2024      DEFERIDO  VÍDEOMUSICAL  Registro de Eventos
# 2374       29/01/2024      DEFERIDO    VARIEDADES                  NaN
# 2375       06/05/2024      DEFERIDO  VÍDEOMUSICAL  Registro de Eventos
# 2376       29/01/2024      DEFERIDO  DOCUMENTÁRIO                  NaN
# 2377       16/05/2024      DEFERIDO        FICÇÃO                  NaN
#
#                                      CLASSIFICACAO_OBRA  \
# 0     BRASILEIRA INDEPENDENTE CONSTITUINTE DE ESPAÇO...
# 1         BRASILEIRA CONSTITUINTE DE ESPAÇO QUALIFICADO
# 2     BRASILEIRA INDEPENDENTE CONSTITUINTE DE ESPAÇO...
# 3         BRASILEIRA CONSTITUINTE DE ESPAÇO QUALIFICADO
# 4         BRASILEIRA CONSTITUINTE DE ESPAÇO QUALIFICADO
# ...                                                 ...
# 2373  BRASILEIRA INDEPENDENTE CONSTITUINTE DE ESPAÇO...
# 2374      BRASILEIRA CONSTITUINTE DE ESPAÇO QUALIFICADO
# 2375  BRASILEIRA INDEPENDENTE CONSTITUINTE DE ESPAÇO...
# 2376  BRASILEIRA INDEPENDENTE CONSTITUINTE DE ESPAÇO...
# 2377      BRASILEIRA CONSTITUINTE DE ESPAÇO QUALIFICADO
#
#                   ORGANIZACAO_TEMPORAL DURACAO_TOTAL_MINUTOS  \
# 0      SERIADA EM MÚLTIPLAS TEMPORADAS                   460
# 1      SERIADA EM MÚLTIPLAS TEMPORADAS                   104
# 2                          NÃO SERIADA                  76,6
# 3     SERIADA DE DURAÇÃO INDETERMINADA                  1500
# 4                          NÃO SERIADA                    46
# ...                                ...                   ...
# 2373                       NÃO SERIADA                   3,9
# 2374        SERIADA EM TEMPORADA ÚNICA                  3520
# 2375                       NÃO SERIADA                   2,0
# 2376                       NÃO SERIADA                  14,0
# 2377                       NÃO SERIADA                   3,5
#
#       QUANTIDADE_EPISODIOS  ANO_PRODUCAO_INICIAL  ANO_PRODUCAO_FINAL  \
# 0                     10.0                2024.0              2024.0
# 1                      8.0                2023.0              2023.0
# 2                      NaN                2024.0                 NaN
# 3                     50.0                2024.0              2024.0
# 4                      NaN                2024.0                 NaN
# ...                    ...                   ...                 ...
# 2373                   NaN                2023.0                 NaN
# 2374                  44.0                2024.0              2024.0
# 2375                   NaN                2024.0                 NaN
# 2376                   NaN                2024.0                 NaN
# 2377                   NaN                2024.0                 NaN
#
#                             SEGMENTO_DESTINACAO_INICIAL  \
# 0     COMUNICAÇÃO ELETRÔNICA DE MASSA POR ASSINATURA...
# 1            RADIODIFUSÃO DE SONS E IMAGENS (TV ABERTA)
# 2     COMUNICAÇÃO ELETRÔNICA DE MASSA POR ASSINATURA...
# 3     COMUNICAÇÃO ELETRÔNICA DE MASSA POR ASSINATURA...
# 4            RADIODIFUSÃO DE SONS E IMAGENS (TV ABERTA)
# ...                                                 ...
# 2373         RADIODIFUSÃO DE SONS E IMAGENS (TV ABERTA)
# 2374         RADIODIFUSÃO DE SONS E IMAGENS (TV ABERTA)
# 2375  COMUNICAÇÃO ELETRÔNICA DE MASSA POR ASSINATURA...
# 2376                                    OUTROS MERCADOS
# 2377                                  SALAS DE EXIBIÇÃO
#
#      COPRODUCAO_INTERNACIONAL                                     REQUERENTE  \
# 0                         NÃO                     MOOD HUNTER PRODUÇÕES LTDA
# 1                         NÃO             UNIVERSIDADE FEDERAL DE OURO PRETO
# 2                         NÃO                             OLÉ PRODUÇÕES LTDA
# 3                         NÃO                          PLAYTV TELEVISÃO LTDA
# 4                         NÃO                            JOANA ARANHA MONCAU
# ...                       ...                                            ...
# 2373                      NÃO       NAVEGADOR MÚSICA PRODUÇÃO E EVENTOS LTDA
# 2374                      NÃO                 TVSBT CANAL 4 DE SAO PAULO S/A
# 2375                      NÃO         47.707.461 BARBARA DA SILVA FIGUEIREDO
# 2376                      NÃO                       CAULI FERNANDES OLIVEIRA
# 2377                      NÃO  36.118.675 RENATA ALEXANDRE MONTEIRO DA SILVA
#
#          CNPJ_REQUERENTE UF_REQUERENTE MUNICIPIO_REQUERENTE
# 0     06.177.126/0001-12            SP            SÃO PAULO
# 1     23.070.659/0001-10            MG           OURO PRETO
# 2     09.019.897/0001-70            SP            SÃO PAULO
# 3     07.121.705/0001-06            SP            SÃO PAULO
# 4          PESSOA FÍSICA            SP            SÃO PAULO
# ...                  ...           ...                  ...
# 2373  02.899.488/0001-66            MG       BELO HORIZONTE
# 2374  45.039.237/0001-14            SP               OSASCO
# 2375  47.707.461/0001-62            SP            SÃO PAULO
# 2376       PESSOA FÍSICA            SP               SANTOS
# 2377  36.118.675/0001-87            RJ       RIO DE JANEIRO
#
# [2378 rows x 18 columns]
